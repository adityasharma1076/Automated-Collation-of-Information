# %%
import bs4
import requests
import pandas as pd
import numpy as np
import os

import warnings
warnings.filterwarnings("ignore")

# %%
import datetime

now = datetime.datetime.now()


Today_time = now.strftime("%H:%M")

Today_date = now.strftime("%Y-%m-%d")

# %%
def fix_url(url_t):
    prefix = 'http://news.mit.edu'
    
    return (prefix+url_t)

# %%
MIT = pd.read_csv('MIT_Text')
#MIT.drop(['Unnamed: 0'],axis=1,inplace=True)
MIT = MIT[['Source','Heading','Category','Date','Time','URL','Text']]

outname ='MIT_Text'

root = 'Backup/'
if not os.path.exists(root):
    os.mkdir(root)
date_today= Today_date +'/'
outdir=root+ date_today[:-1]
if not os.path.exists(outdir):
    os.mkdir(outdir)
fullname = os.path.join(outdir, outname)

MIT.to_csv(fullname,index=False, encoding='utf-8')

# %%
link = 'http://news.mit.edu/'
res = requests.get(link)
soup=bs4.BeautifulSoup(res.text,'lxml')

# %%
List1 = ['http://news.mit.edu/topic/algorithms',
        'http://news.mit.edu/topic/computer-vision',
        'http://news.mit.edu/topic/machine-learning',
        'http://news.mit.edu/topic/big-data',
        'http://news.mit.edu/topic/software',
        'http://news.mit.edu/topic/cyber-security',
        'http://news.mit.edu/topic/networks',
        'http://news.mit.edu/topic/natural-language-processing',
        'http://news.mit.edu/topic/web-development',
        'http://news.mit.edu/topic/computers',
         'http://news.mit.edu/engineering']
       
List2 =['http://news.mit.edu/topic/robotics',
       'http://news.mit.edu/topic/electronics',
       'http://news.mit.edu/topic/research',
       'http://news.mit.edu/topic/nanotech',
       'http://news.mit.edu/topic/nasa']

# %%
def get_records(content_d,category):
    temp_records = []
    for temp_record in content_d:
        URL = fix_url(temp_record.find('a')['href'])
        Heading = temp_record.find('h3').text
        #Summary = temp_record.find('p').text
        Date = temp_record.find('em').text
        Category = category
        Source = 'MIT News'
        Time = '-'
        Text = ''
        temp_records.append((Source,Heading,Category,Date,Time,URL,Text))
    return temp_records

# %%
records = []
for list_element in List1:
    category = 'Computer Science'
    
    list_element_url = list_element
    res_element = requests.get(list_element_url)
    soup_element=bs4.BeautifulSoup(res_element.text,'lxml')
    content = soup_element.find('ul',{'class':'view-news-items'}).findAll('li')
    rec = get_records(content,category)
    records.append(rec)
    

for list_element in List2:
    category = str.split(list_element,'/')[-1]
    
    list_element_url = list_element
    res_element = requests.get(list_element_url)
    soup_element=bs4.BeautifulSoup(res_element.text,'lxml')
    content = soup_element.find('ul',{'class':'view-news-items'}).findAll('li')
    rec = get_records(content,category.capitalize())
    records.append(rec)

# %%
flat_list = []
for sublist in records:
    for item in sublist:
        flat_list.append(item)

# %%
df=pd.DataFrame(flat_list,columns=['Source','Heading','Category','Date','Time','URL','Text'])
df['Date'] = pd.to_datetime(df['Date'])

# %%
df
# Out:
#        Source                                            Heading  \
# 0    MIT News    Faster video recognition for the smartphone era
# 1    MIT News    This is how a “fuzzy” universe may have looked
# 2    MIT News     System helps smart devices find their position
# 3    MIT News    Using algorithms to build a map of the placenta
# 4    MIT News       Using math to blend musical notes seamlessly
# 5    MIT News  How cities can leverage citizen data while pro...
# 6    MIT News          What a little more computing power can do
# 7    MIT News  Detecting patients’ pain levels via their brai...
# 8    MIT News  MIT’s fleet of autonomous boats can now shapes...
# 9    MIT News  IBM gives artificial intelligence computing at...
# 10   MIT News  Artificial intelligence could help data center...
# 11   MIT News  Using Wall Street secrets to reduce the cost o...
# 12   MIT News  Automating artificial intelligence for medical...
# 13   MIT News  Model predicts cognitive decline due to Alzhei...
# 14   MIT News  Why did my classifier just mistake a turtle fo...
# 15   MIT News  Want to know what software-driven health care ...
# 16   MIT News    Making it easier to program and protect the web
# 17   MIT News  Automated system generates robotic parts for n...
# 18   MIT News  Making wireless communication more energy effi...
# 19   MIT News  Teaching artificial intelligence to create vis...
# 20   MIT News          What a little more computing power can do
# 21   MIT News  Why did my classifier just mistake a turtle fo...
# 22   MIT News  Teaching artificial intelligence to create vis...
# 23   MIT News  Teaching artificial intelligence to connect se...
# 24   MIT News  A 3-D printer powered by machine vision and ar...
# 25   MIT News  For better deep neural network vision, just ad...
# 26   MIT News  Deep-learning technique reveals “invisible” ob...
# 27   MIT News  Fleets of drones could aid searches for lost h...
# 28   MIT News     Machines that learn language more like kids do
# 29   MIT News                     Recognizing the partially seen
# ..        ...                                                ...
# 280  MIT News  MIT engineers build advanced microprocessor ou...
# 281  MIT News  Ultrathin 3-D-printed films convert energy of ...
# 282  MIT News  A new way to deliver drugs with pinpoint targe...
# 283  MIT News        A single-photon source you can make at home
# 284  MIT News  Yearlong hackathon engages nano community arou...
# 285  MIT News  MIT “Russian Doll” tech lands $7.9M internatio...
# 286  MIT News  Artificial “muscles” achieve powerful pulling ...
# 287  MIT News                    Enriching solid-state batteries
# 288  MIT News  Micro ring resonator has highest silicon carbi...
# 289  MIT News  MIT.nano announces founding members of its cor...
# 290  MIT News  Astronomers use giant galaxy cluster as X-ray ...
# 291  MIT News           Computing and the search for new planets
# 292  MIT News  Scientists detect tones in the ringing of a ne...
# 293  MIT News                        Taking the next giant leaps
# 294  MIT News  For first time, astronomers catch asteroid in ...
# 295  MIT News  Rocky, Earth-sized exoplanet is missing an atm...
# 296  MIT News                           The music of the spheres
# 297  MIT News  TESS discovers three new planets nearby, inclu...
# 298  MIT News  Scientists look to synthetic biology and 3-D p...
# 299  MIT News     Behind the scenes of the Apollo mission at MIT
# 300  MIT News  Breaching a “carbon threshold” could lead to m...
# 301  MIT News                         An escape route for carbon
# 302  MIT News  Algorithm tells robots where nearby humans are...
# 303  MIT News  Maria Zuber awarded the Gerard P. Kuiper Prize...
# 304  MIT News  MIT team places second in 2019 NASA BIG Idea C...
# 305  MIT News  Tissue chip headed to International Space Stat...
# 306  MIT News  North Atlantic Ocean productivity has dropped ...
# 307  MIT News        TESS discovers its first Earth-sized planet
# 308  MIT News  MIT celebrates 50th anniversary of historic mo...
# 309  MIT News  Microgravity research after the International ...
#
#              Category       Date Time  \
# 0    Computer Science 2019-10-11    -
# 1    Computer Science 2019-10-03    -
# 2    Computer Science 2019-10-02    -
# 3    Computer Science 2019-10-02    -
# 4    Computer Science 2019-09-27    -
Headings = s1['Heading']

def fix_heading(x):
    for i in Headings:
        if(i==x):
            return 'nil'
    return x
df['Heading'] = df['Heading'].apply(fix_heading)

# %%
df = df[df['Heading']!='nil']
df.head()
# Out:
#        Source                                            Heading  \
# 17   MIT News                  Machine learning you can dance to
# 18   MIT News  Notation system allows scientists to communica...
# 127  MIT News  Lincoln Laboratory's new artificial intelligen...
# 128  MIT News       Using math to blend musical notes seamlessly
# 129  MIT News  Photovoltaic-powered sensors for the “internet...
#
#              Category       Date Time  \
# 17   Computer Science 2019-09-18    -
# 18   Computer Science 2019-09-18    -
# 127  Computer Science 2019-09-27    -
# 128  Computer Science 2019-09-27    -
# 129  Computer Science 2019-09-27    -
#
#                                                    URL Text
# 17   http://news.mit.edu/2019/machine-learning-you-...
# 18   http://news.mit.edu/2019/bigsmiles-notation-sy...
# 127  http://news.mit.edu/2019/lincoln-laboratory-ai...
# 128  http://news.mit.edu/2019/math-portamento-music...
# 129  http://news.mit.edu/2019/photovoltaic-rfid-sen...

# %%
def fix_text(x):
    try:
        res = requests.get(x,headers={'User-Agent': 'Mozilla/5.0'})
        soup = bs4.BeautifulSoup(res.text,'lxml')
    
        txt = soup.find('div',{'class':'field-item'}).text
    except:
        return '-'
    n = str.split(txt,'\n')
    a = ''
    for i in n:
        a=a+' '+i
        
    o = str.split(a,'\xa0')
    b = ''
    for i in o:
        b=b+' '+i
    return b    

df['Text'] = df['URL'].apply(fix_text)

# %%
MIT.head()
# Out:
#      Source                                            Heading  \
# 0  MIT News   MIT named No. 3 university by U.S. News for 2020
# 1  MIT News  Breakthrough Prize in Fundamental Physics awar...
# 2  MIT News             How to make a book last for millennia
# 3  MIT News                        Taking the next giant leaps
# 4  MIT News           Cleaning up hydrogen peroxide production
#
#            Category        Date Time  \
# 0  Computer Science  2019-09-09    -
# 1  Computer Science  2019-09-06    -
# 2          Research  2019-09-06    -
# 3              Nasa  2019-09-05    -
# 4  Computer Science  2019-09-05    -
#
#                                                  URL  \
# 0  http://news.mit.edu/2019/mit-named-no-3-univer...
# 1  http://news.mit.edu/2019/breakthrough-prize-ph...
# 2  http://news.mit.edu/2019/temple-scroll-ancient...
# 3  http://news.mit.edu/2019/taking-next-giant-lea...
# 4  http://news.mit.edu/2019/solugen-hydrogen-pero...
#
#                                                 Text
# 0    For a second year in a row, U.S. News and Wo...
# 1    The Event Horizon Telescope (EHT) Collaborat...
# 2    First discovered in 1947 by Bedouin shepherd...
# 3    In July, the world celebrated the 50th anniv...
# 4    The most common process for making hydrogen ...

# %%
temp = MIT.append(df)
temp['Date'] = pd.to_datetime(temp['Date'])
temp = temp.sort_values(by=['Date'],ascending=False).reset_index().drop(['index'],axis=1)
temp.to_csv('MIT_Text')

# %%
outname ='MIT-'+str(Today_date)+'.csv'
root = 'Uncategorized Data/'
if not os.path.exists(root):
    os.mkdir(root)
date_today= Today_date +'/'
outdir=root+ date_today[:-1]
if not os.path.exists(outdir):
    os.mkdir(outdir)
fullname = os.path.join(outdir, outname)

# %%
df.to_csv(fullname,index=False,encoding='utf-8')
