# %%
import os
import glob
import pandas as pd
from sklearn.externals import joblib
import numpy as np
import sys

import warnings
warnings.filterwarnings("ignore")

# %%
import datetime

now = datetime.datetime.now()


Today_time = now.strftime("%H:%M")

Today_date = now.strftime("%Y-%m-%d")

# %%
extension = 'csv'
string = 'Uncategorized Data/'+Today_date+'/*.{}'

all_filenames = [i for i in glob.glob(string.format(extension))]

# %%
df = pd.concat([pd.read_csv(f) for f in all_filenames ])

# %%
df = df.sort_values(by='Date',ascending=False)
df = df[df['Text']!='-']
df = df.drop_duplicates(subset='Heading',keep='last').reset_index(drop=True)

# %%
df['Category'].value_counts()
# Out:
# ACM                     12
# Earth & Climate          9
# Research                 9
# Science & Society        9
# Mind & Brain             8
# Matter & Energy          8
# Space & Time             7
# Computers & Math         6
# Robotics                 5
# Computer Science         5
# Education & Learning     4
# Science & Technology     3
# Semiconductors           3
# Nanotech                 2
# Aerospace                2
# Business & Industry      2
# Social Sciences          1
# Nasa                     1
# Name: Category, dtype: int64

# %%
def fix_cat(x):
    if x[0]==' ':
        return x[1:]
    else:
        return x
df['Category'] = df['Category'].apply(fix_cat)

# %%
def fix_g(x):
    if 'Q&A' in x:
        return 'nil'
    elif '3 Questions:' in x:
        return 'nil'
    else:
        return x
df['Heading'] = df['Heading'].apply(fix_g)
df = df[df['Heading']!='nil']
df = df[df['Text']!='']

# %%
def fix_cat(x):
    if (x=='Cybersecurity'):
        return 'Computer Science'
    elif (x=='Living Well' or x=='Mind & Brain' or x=='Health & Medicine'):
        return 'Health'
    elif(x=='Plants & Animals' or x=='Earth & Climate'):
        return 'Environment'
    elif(x=='Business & Industry' or x=='Education & Learning' or x=='Gadgets'):
        return 'Society'
    elif(x=='NASA' or x=='Aerospace' or x=='Nasa'):
        return 'Space & Time'
    elif(x=='Research'):
        return 'Research'
    elif(x=='Telecommunications' or x=='Semiconductors' or x=='electronics' or x=='Nanoscience and nanotechnology' or x=='Green Tech' or x=='Nanotech'):
        return 'Electronics and Technology'
    elif(x=='International' or x=='Entrepreneurship' or x=='Undergraduate' or x=='Humanities'):
        return 'Others'
    elif(x=='Social Sciences' or x=='Science & Technology' or x=='Science & Society'):
        return 'Science'
    elif(x=='Fossils & Ruins' or x=='Energy'):
        return 'Matter & Energy'
    else:
        return x
    

df['Category'] = df['Category'].apply(fix_cat)

# %%
df['Category'].value_counts()
# Out:
# Science                       13
# ACM                           12
# Space & Time                  10
# Environment                    9
# Research                       9
# Matter & Energy                8
# Health                         8
# Society                        6
# Computers & Math               6
# Computer Science               5
# Robotics                       5
# Electronics and Technology     5
# Name: Category, dtype: int64

# %%
df=df.sort_values(by='Category')
df = df.reset_index(drop=True)

# %%
temp = pd.DataFrame.copy(df)

# %%
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
import nltk
import re
import string
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from num2words import num2words
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer("english")

nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package wordnet to C:\Users\drago/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\drago/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to C:\Users\drago/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
stop = ['a', 'about', 'above', 'across', 'after', 'afterwards', 'again', 'against', 'all', 'almost', 'alone',
             'along', 'already', 'also', 'although', 'always', 'am', 'among', 'amongst', 'amoungst', 'amount',
             'an', 'and', 'another', 'any', 'anyhow', 'anyone', 'anything', 'anyway', 'anywhere', 'are', 'around',
             'as', 'at', 'back', 'be', 'became', 'because', 'become', 'becomes', 'becoming', 'been', 'before',
             'beforehand', 'behind', 'being', 'below', 'beside', 'besides', 'between', 'beyond', 'bill', 'both',
             'bottom', 'but', 'by', 'call', 'can', 'cannot', 'cant', 'co', 'con', 'could', 'couldnt', 'cry', 'de',
             'describe', 'detail', 'did', 'do', 'does', 'doing', 'don', 'done', 'down', 'due', 'during', 'each', 'eg',
             'eight', 'either', 'eleven', 'else', 'elsewhere', 'empty', 'enough', 'etc', 'even', 'ever', 'every', 'everyone',
             'everything', 'everywhere', 'except', 'few', 'fifteen', 'fify', 'fill', 'find', 'fire', 'first', 'five', 'for',
             'former', 'formerly', 'forty', 'found', 'four', 'from', 'front', 'full', 'further', 'get', 'give', 'go', 'had',
             'has', 'hasnt', 'have', 'having', 'he', 'hence', 'her', 'here', 'hereafter', 'hereby', 'herein', 'hereupon',
             'hers', 'herself', 'him', 'himself', 'his', 'how', 'however', 'hundred', 'i', 'ie', 'if', 'in', 'inc', 'indeed',
             'interest', 'into', 'is', 'it', 'its', 'itself', 'just', 'keep', 'last', 'latter', 'latterly', 'least', 'less',
             'ltd', 'made', 'many', 'may', 'me', 'meanwhile', 'might', 'mill', 'mine', 'more', 'moreover', 'most', 'mostly',
             'move', 'much', 'must', 'my', 'myself', 'name', 'namely', 'neither', 'never', 'nevertheless', 'next', 'nine',
             'no', 'nobody', 'none', 'noone', 'nor', 'not', 'nothing', 'now', 'nowhere', 'of', 'off', 'often', 'on', 'once',
             'one', 'only', 'onto', 'or', 'other', 'others', 'otherwise', 'our', 'ours', 'ourselves', 'out', 'over', 'own',
             'part', 'per', 'perhaps', 'please', 'put', 'rather', 're', 's', 'same', 'see', 'seem', 'seemed', 'seeming',
             'seems', 'serious', 'several', 'she', 'should', 'show', 'side', 'since', 'sincere', 'six', 'sixty', 'so', 
             'some', 'somehow', 'someone', 'something', 'sometime', 'sometimes', 'somewhere', 'still', 'such', 'system',
             't', 'take', 'ten', 'than', 'that', 'the', 'their', 'theirs', 'them', 'themselves', 'then', 'thence', 'there',
             'thereafter', 'thereby', 'therefore', 'therein', 'thereupon', 'these', 'they', 'thickv', 'thin', 'third', 'this',
             'those', 'though', 'three', 'through', 'throughout', 'thru', 'thus', 'to', 'together', 'too', 'top', 'toward',
             'towards', 'twelve', 'twenty', 'two', 'un', 'under', 'until', 'up', 'upon', 'us', 'very', 'via', 'was', 'we',
             'well', 'were', 'what', 'whatever', 'when', 'whence', 'whenever', 'where', 'whereafter', 'whereas', 'whereby',
             'wherein', 'whereupon', 'wherever', 'whether', 'which', 'while', 'whither', 'who', 'whoever', 'whole', 'whom',
             'whose', 'why', 'will', 'with', 'within', 'without', 'would', 'yet', 'you', 'your', 'yours', 'yourself',
             'yourselves',
       'csail','faculty','honored','society','abroad','inner','cambridge','academic','school','interdisciplinary','athlete','senior','thirty','mit','team','mit researcher','laboratory','member','student','drug','approach','professor','graduate','phd',
    ]

# %%
stop_words = stopwords.words('english')
stop_words.extend(stop)
stop = set(stop_words)
exclude = set(string.punctuation)
lemma = WordNetLemmatizer()

# %%
def remove_apostrophe(data):
    return np.char.replace(data, "'", "")
def remove_punctuation(data):
    for i in (exclude):
        data = np.char.replace(data, i, ' ')
        data = np.char.replace(data, "  ", " ")
    data = np.char.replace(data, ',', '')
    return data

def convert_numbers(data):
    tokens = word_tokenize(str(data))
    new_text = ""
    for w in tokens:
        try:
            w = num2words(int(w))
        except:
            a = 0
        new_text = new_text + " " + w
    new_text = np.char.replace(new_text, "-", " ")
    return new_text

def clean(data):
    stop_free = " ".join([i for i in data.lower().split() if i not in stop])
    normalized = " ".join(lemma.lemmatize(word) for word in stop_free.split())
    processed = re.sub(r"\d+","",normalized)
    #y = processed.split()
    return processed

# %%
temp['Text'] = temp['Text'].apply(remove_apostrophe)
temp['Text'] = temp['Text'].apply(remove_punctuation)
temp['Text'] = temp['Text'].apply(convert_numbers)
temp['Text'] = temp['Text'].apply(clean)

# %%
my_tags = temp['Category'].unique()
my_tags
# Out:
# array(['ACM', 'Computer Science', 'Computers & Math',
#        'Electronics and Technology', 'Environment', 'Health',
#        'Matter & Energy', 'Research', 'Robotics', 'Science', 'Society',
#        'Space & Time'], dtype=object)

# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics import accuracy_score
from nltk.tokenize import word_tokenize

nb_load = joblib.load('NaiveBayes_model_5.pkl')

# %%
if temp.empty:
    print()
    print()
    sys.exit('NO News to Update')
y_pred = nb_load.predict(temp['Text'])

# %%
all_categories= ['Computer Science',
        'Electronics and Technology',
        'Environment',
        'Health',
        'Matter & Energy',
        'Others',
        'Robotics',
        'Society',
        'Space & Time',
         'Telecom']

# %%
weights= {
        'Computer Science':0.21,
        'Electronics and Technology':0.17,
        'Environment':0.08,
        'Health':0.04,
        'Matter & Energy':0.08,
        'Others':0.07,
        'Robotics':0.11,
        'Society':0.05,
        'Space & Time':0.10,
        'Telecom':0.09
        }

# %%
#present_tags = {k: weights[k] for k in my_tags if k in weights}
#present_tags

# %%
def sum(x):
    arr = np.asarray(x) * np.asarray(weights_values)
    return np.sum(arr)

# %%
test_prob = nb_load.predict_proba(temp['Text'])
weights_df = pd.DataFrame(test_prob,columns=all_categories)

# %%
weights_df.head()
# Out:
#    Computer Science  Electronics and Technology  Environment    Health  \
# 0          0.150583                    0.011395     0.079190  0.016019
# 1          0.509990                    0.008232     0.004762  0.006871
# 2          0.362583                    0.120015     0.041219  0.069660
# 3          0.017685                    0.010419     0.079190  0.046724
# 4          0.123973                    0.112181     0.037683  0.555203
#
#    Matter & Energy    Others  Robotics   Society  Space & Time   Telecom
# 0         0.132107  0.006274  0.046860  0.014392      0.529916  0.013264
# 1         0.026100  0.002672  0.352453  0.025175      0.028057  0.035687
# 2         0.271264  0.009772  0.046155  0.022927      0.034733  0.021672
# 3         0.746890  0.010607  0.007320  0.032194      0.042975  0.005997
# 4         0.060080  0.008206  0.029977  0.032385      0.029304  0.011008

# %%
weights_values = [ v for v in weights.values() ]
weights_df['Weight'] = weights_df.apply(sum,axis=1)


temp['Category_predicted'] = y_pred
weighs = weights_df['Weight']
weighs = np.asarray(weighs)

# %%
temp['weights'] = weighs

# %%
df['Category_predicted']=temp['Category_predicted']
df['weights'] = temp['weights']

# %%
df.sort_values(by='weights',ascending=False)
# Out:
#            Source                                            Heading  \
# 6             ACM  Companies Use Cyber Ranges to Practice Securit...
# 54       MIT News  MIT’s fleet of autonomous boats can now shapes...
# 11            ACM                 Developing Embedded Systems Faster
# 10            ACM      AI System Passed an Eighth-Grade Science Test
# 26       MIT News  MIT engineers build advanced microprocessor ou...
# 24       MIT News  Ultrathin 3-D-printed films convert energy of ...
# 1             ACM  Construction Robots Learn to Excavate by Mimic...
# 18  Science Daily                    AI Learns to Model Our Universe
# 7             ACM             Spreading Light Over Quantum Computers
# 8             ACM  French Researcher Hacks into Moscow's New E-Vo...
# 25           IEEE                           AI at the Speed of Light
# 23           IEEE  A Carbon Nanotube Microprocessor Mature Enough...
# 16       MIT News  Legatum Center announces 2019-20 fellowship class
# 46  Science Daily  New Insulation Technique Paves the Way for Mor...
# 21  Science Daily  A New Alphabet to Write and Read Quantum Messa...
# 2             ACM    Researchers Use AI to Plot Green Route to Nylon
# 22  Science Daily  Electronic Glove Offers 'Humanlike' Features f...
# 20  Science Daily  AI Learns the Language of Chemistry to Predict...
# 15       MIT News  David H. Koch, prominent supporter of cancer r...
# 12       MIT News   Overcoming obstacles with an electric hovercraft
# 52  Science Daily  New Material State: Quantum Disordered Liquid-...
# 9             ACM      Entanglement Sent Over 50 km of Optical Fiber
# 35  Science Daily  Artificial Intelligence Used to Recognize Prim...
# 19  Science Daily  An Astonishing Parabola Trick: Unusual Magneti...
# 50  Science Daily  Secret Messages Hidden in Light-Sensitive Poly...
# 13       MIT News  Students spearhead group to enhance the gradua...
# 17  Science Daily  At the Edge of Chaos, Powerful New Electronics...
# 49  Science Daily  Laser-Based Ultrasound Approach Provides New D...
# 51  Science Daily  Biophysics: Stretching Proteins With Magnetic ...
# 74  https://www.sciencedaily.com/releases/2019/08/...
# 34  https://www.sciencedaily.com/releases/2019/09/...
# 39  https://www.sciencedaily.com/releases/2019/09/...
# 69  https://news.stanford.edu/2019/08/27/tradition...
# 36  https://www.sciencedaily.com/releases/2019/09/...
# 68  https://www.sciencedaily.com/releases/2019/08/...
# 14  http://news.mit.edu/2019/work-future-report-te...
# 57  http://news.mit.edu/2019/summer-mit-reveals-co...
# 72  https://news.stanford.edu/2019/09/03/poverty-d...
# 60  http://news.mit.edu/2019/catalogue-human-diges...
# 84  https://www.sciencedaily.com/releases/2019/08/...
# 79  https://www.sciencedaily.com/releases/2019/08/...
# 38  https://www.sciencedaily.com/releases/2019/09/...
# 28  https://www.sciencedaily.com/releases/2019/09/...
# 81  https://www.sciencedaily.com/releases/2019/08/...
# 59  http://news.mit.edu/2019/tech-phone-tuberculos...
# 85  https://www.sciencedaily.com/releases/2019/08/...
# 48  https://www.sciencedaily.com/releases/2019/09/...
# 37  https://www.sciencedaily.com/releases/2019/09/...
# 83  https://www.sciencedaily.com/releases/2019/08/...
# 42  https://www.sciencedaily.com/releases/2019/09/...
# 40  https://www.sciencedaily.com/releases/2019/08/...
# 44  https://www.sciencedaily.com/releases/2019/09/...
# 41  https://www.sciencedaily.com/releases/2019/09/...
# 67  https://www.sciencedaily.com/releases/2019/08/...
#
#                                                  Text  \
# 6          Companies Use Cyber Ranges to Practice ...
# 54    MIT’s fleet of robotic boats has been update...
# 11      Developing Embedded Systems Faster     Fra...
# 10         AI System Passed an Eighth-Grade Scienc...
# 26    After years of tackling numerous design and ...
# 24    MIT researchers have developed a simple, low...
# 1          Construction Robots Learn to Excavate b...
# 18     Researchers seek to understand our Universe...
# 7       Spreading Light Over Quantum Computers    ...
# 8       French Researcher Hacks into Moscow's New ...
# 25        Neural networks shine for solving tough ...
# 23        Engineers at MIT and Analog Devices have...
# 16    The Legatum Center for Development and Entre...
# 46     Computer chips are getting increasingly sma...
# 21     Let us imagine the following situation: Ann...
# 2       Researchers Use AI to Plot Green Route to ...
# 22     An electronic glove, or e-glove, developed ...
# 20     A central challenge in drug discovery and m...
# 15    David H. Koch ’62, SM ’63, one of the most i...
# 12    Through dedication and a willingness to face...
# 52     In the paper "Field-tunable quantum disorde...
# 9       Entanglement Sent Over 50 km of Optical Fi...
# 35     'For species like chimpanzees, which have c...
# 19     We all know that our left hand is different...
# 50     In a leap forward in this field, researcher...
# 13    What do graduate students in engineering wan...
# 17     A team of physicists at the University of G...
# 49     A team of researchers is using ultrasonic n...
# 51     The mechanical forces required to activate ...
# 82     The study, forthcoming in the January issue...
# ..                                                ...
# 3          3.8-Million-Year-Old Fossil Cranium Unv...
# 76     "Through this crowdsourced data, we can see...
# 78     After long negotiations, the international ...
# 77     The Paris Agreement, signed in 2015, requir...
# 29     This seeming contradiction is due to the fa...
# 74     "This crisis is different because the sprea...
# 34     The new approach could be used to study pot...
# 39     In contrast, as the sclerae of apes' eyes i...
# 69     It costs more than a new iPhone XS, and it’...
# 36     In a collaboration between the National Mus...
# 68     As early farming communities gave rise to l...
# 14    Automation is not likely to eliminate millio...
# 57    Meucci Ilunga seems to know something about ...
# 72     No drug can cure a paradox. That basic trut...
# 60    The human digestive tract is home to thousan...
# 84     Legend has it that millennials, specificall...
# 79     In both the US and globally, there is growi...
# 38     Previous research (the ACTIB trial) led by ...
# 28     That, in turn, raises the cost and environm...
# 81     After surveying more than 3,170 students an...
# 59    For tuberculosis patients, complying with a ...
# 85     The Victorian Childhood Hearing Impairment ...
# 48     A study published today in JAMA compared th...
# 37     The study into the role a protein known as ...
# 83     The University of York-led study examined g...
# 42     According to researchers at Wake Forest Sch...
# 40     Dr. Karli Kondo of the VA Evidence Synthesi...
# 44     "We have found that a specific cell recepto...
# 41     The new research, published online in the j...
# 67     The research -- based on a survey of more t...
#
#             Category_predicted   weights
# 6             Computer Science  0.176328
# 54            Computer Science  0.174268
# 11            Computer Science  0.167777
# 10            Computer Science  0.164176
# 26  Electronics and Technology  0.163979
# 24  Electronics and Technology  0.162981
# 1             Computer Science  0.157474
# 18            Computer Science  0.156437
# 7   Electronics and Technology  0.156111
# 8             Computer Science  0.154879
# 25            Computer Science  0.153117
# 23  Electronics and Technology  0.148325
# 16            Computer Science  0.147541
# 46  Electronics and Technology  0.147489
# 21  Electronics and Technology  0.144645
# 2             Computer Science  0.136661
# 22            Computer Science  0.135726
# 20            Computer Science  0.133098
# 15  Electronics and Technology  0.130876
# 12            Computer Science  0.130460
# 52  Electronics and Technology  0.129199
# 9   Electronics and Technology  0.127981
# 35            Computer Science  0.127624
# 19  Electronics and Technology  0.126466
# 50  Electronics and Technology  0.125957
# 13                     Society  0.125070
# 17  Electronics and Technology  0.124432
# 49  Electronics and Technology  0.124360
# 51  Electronics and Technology  0.121309
# 82            Computer Science  0.121033
# ..                         ...       ...
# 3              Matter & Energy  0.081435
# 76             Matter & Energy  0.080712
# 78                 Environment  0.080227
# 77                 Environment  0.080055
# 29                 Environment  0.079944
# 74                     Society  0.079888
# 34                 Environment  0.079811
# 39                     Society  0.077306
# 69                 Environment  0.077113
# 36                 Environment  0.076874
# 68                     Society  0.075783
# 14                     Society  0.070856
# 57                      Health  0.067330
# 72                 Environment  0.066453
# 60                      Health  0.059057
# 84                     Society  0.055957
# 79                     Society  0.054295
# 38                      Health  0.054111
# 28                      Health  0.052851
# 81                     Society  0.052688
# 59                      Health  0.049543
# 85                      Health  0.048292
# 48                      Health  0.044689
# 37                      Health  0.044442
# 83                      Health  0.043545
# 42                      Health  0.042126
# 40                      Health  0.041663
# 44                      Health  0.041100
# 41                      Health  0.041014
# 67                      Health  0.040747
#
# [96 rows x 9 columns]

# %%
df = df.sort_values(by='weights',ascending=False).reset_index(drop=True)

# %%
outname =str(Today_date)+'.csv'
root = 'Prioritized Data/'
if not os.path.exists(root):
    os.mkdir(root)
date_today= Today_date +'/'
outdir=root+ date_today[:-1]
if not os.path.exists(outdir):
    os.mkdir(outdir)
fullname = os.path.join(outdir, outname)

# %%
df.to_csv(fullname)

# %%
col = ['Heading', 'URL']
to_print = df[col].head(12)

# %%
outname =str(Today_date)+'.xlsx'
root = 'To Upload/'
if not os.path.exists(root):
    os.mkdir(root)
date_today= Today_date +'/'
outdir=root+ date_today[:-1]
if not os.path.exists(outdir):
    os.mkdir(outdir)
print_name = os.path.join(outdir, outname)

# %%
to_print.to_excel(print_name)
